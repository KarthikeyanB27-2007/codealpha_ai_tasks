# %% [markdown]
# <a href="https://colab.research.google.com/github/KarthikeyanB27-2007/codealpha_ai_tasks/blob/main/Language_Translator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install googletrans==4.0.0-rc1

# %%
from googletrans import Translator

translator = Translator()

text = input("Enter text to translate: ")
source_lang = input("Source language (e.g. en, ta, hi): ")
target_lang = input("Target language (e.g. en, ta, hi): ")

translated = translator.translate(text, src=source_lang, dest=target_lang)

print("\nTranslated text:")
print(translated.text)
# Out:
# Enter text to translate: Hi
# Source language (e.g. en, ta, hi): en
# Target language (e.g. en, ta, hi): ta
#
# Translated text:
# வணக்கம்
